# %% [markdown]
# <a href="https://colab.research.google.com/github/VaishKS/3D-U-Net-Prostate-Segmentation/blob/master/src/3D_U-Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Contents
#
# 1. Load data
#     * 1.1. Helper functions for loading the data
#     * 1.2. Generate dataset and export to .pkl files
#     * 1.3. Visualise scans and annotations
#     * 1.4. Class frequencies and weights
# 2. Cross-validation dataset [extension]
# 3. Data augmentation
#     * 3.1. Helper methods for data augmentation
#     * 3.2. Visualise data augmentations
# 4. Data pre-processing
#     * 4.1. Histogram equalisation
#         * 4.1.1. Helper methods for histogram equalisation
#         * 4.1.2. Apply histogram equalisation to dataset
#         * 4.1.3. Visualise histogram equalisation
#     * 4.2. Input/output scaling and IOU evaluation
#         * 4.2.1. Helper functions for input/output scaling and IOU evaluation
#         * 4.2.2. Visualise scaled scans and annotations
# 5. 3D U-Net model
# 6. Model training
#     * 6.1. Generate pre-processed augmented dataset
#     * 6.2. Set model hyperparameters
#     * 6.3. Helper functions for training
#     * 6.4. Train model
# 7. Model inference
#     * 7.1. Visualise predictions
#         * 7.1.1. Example: 'best' prediction
#         * 7.1.2. Example: 'worst' prediction

# %% [markdown]
# # Instructions
#
# 1. Install the relevant Python 3 dependencies specified in *requirements.txt*.
# > `pip3 install -r requirements.txt`
# 2. Download and extract the dataset: __[*3D Prostate Structures*](https://wiki.cancerimagingarchive.net/display/Public/NCI-ISBI+2013+Challenge+-+Automated+Segmentation+of+Prostate+Structures)__ (or directly [here](https://wiki.cancerimagingarchive.net/pages/viewpage.action?pageId=21267207))
# 3. To train the 3D U-Net model, execute cells in sections 1-6.
# 4. To test the trained 3D U-Net model, execute cells in section 7.
#
# *Note:* For interactive plot tool, Jupyter must be run locally (won't work if viewing via Github).
#
# As a starting point, I used the implementation from https://github.com/96imranahmed/3D-Unet.
# My major changes and additions are in sections 1.4, 3.1, 3.2, 4.1, 5, 6.3, 6.4 and 7.

# %%
# !pip install pydicom
# !pip install pynrrd
# Out:
# Collecting pydicom
#   Downloading pydicom-2.3.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 8.1 MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.0
# Collecting pynrrd
#   Downloading pynrrd-0.4.3-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from pynrrd) (1.21.6)
# Installing collected packages: pynrrd
# Successfully installed pynrrd-0.4.3

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# Required modules
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
import time
import os
import sys
import pydicom
import nrrd
import scipy.ndimage
import scipy.misc
import pickle
import random
import skimage
from IPython.core.debugger import set_trace
# %matplotlib notebook

if sys.version_info[0] != 3:
    raise Exception("Python version 3 has to be used!")

print("Currently using")
print("\t numpy ", np.__version__)
print("\t scipy ", scipy.__version__)
print("\t matplotlib ", matplotlib.__version__)
print("\t tensorflow ", tf.__version__)
print("\t pydicom ", pydicom.__version__)
print("\t nrrd ", nrrd.__version__)
print("\t skimage ", skimage.__version__)

np.random.seed(37) # for reproducibility
# Out:
# Currently using
# 	 numpy  1.21.6
# 	 scipy  1.4.1
# 	 matplotlib  3.2.2
# 	 tensorflow  1.15.2
# 	 pydicom  2.3.0
# 	 nrrd  0.4.3
# 	 skimage  0.18.3

# %% [markdown]
# # 1. Load data

# %% [markdown]
# ## 1.1. Helper functions for loading the data
# * read MRI scans (.dcm) and annotations (.nddr)
# * match scans with annotations
# * visualise 2D slices

# %%
def return_dcm(file_path, check_term = 'Prostate'):
    # Read all DCM (slices) files within a directory and order the files based on filename
    out_dcm = {}
    for dirName, subdirList, fileList in os.walk(file_path):
        c_dcm = []
        cur_name = ""
        dir_split = dirName.split("/")
        for f_chk in dir_split:
            if check_term in f_chk:
                cur_name = f_chk
        for filename in fileList:
            if ".dcm" in filename.lower():
                name = os.path.splitext(filename)[0]
                c_dcm.append((os.path.join(dirName,filename), name))
        if len(c_dcm) > 0:
            c_dcm = sorted(c_dcm, key = lambda t: t[1]) # Sort into correct order
            out_dcm[cur_name] = [c[0] for c in c_dcm]   # Store in dictionary
    return out_dcm

def return_nrrd(file_path):
    # Read all NRRD (annotation) files within a directory
    out_nrrd = {}
    for dirName, subdirList, fileList in os.walk(file_path):
        for filename in fileList:
            if ".nrrd" in filename.lower():
                name = filename.split('_')[0] 
                name = name.split('.')[0] # Get annotation name and store in dictionary
                out_nrrd[name] = os.path.join(dirName,filename)
    return out_nrrd

def get_dataset(data_dir, anns_dir):
    # Match DCM volumes with corresponding annotation files
    data_out = []
    shapes = {}
    d_dcm = return_dcm(data_dir)
    d_nrrd = return_nrrd(anns_dir)
    for i in d_nrrd:
      seg, opts = nrrd.read(d_nrrd[i])
      voxels = np.zeros(np.shape(seg))
      # set_trace()
      for j in range(len(d_dcm[i])):
          dicom_ref = pydicom.read_file(d_dcm[i][j])
          found = False
          chk_val = dicom_ref[("0020", "0013")].value 
          # Make sure you get the right slice! This is a bizarre specification thing related to DCM dataset
          # Note, if you just use the default filename ordering you get mismatched slices!
          if int(chk_val.__str__()) - 1 < np.shape(voxels)[-1]:
              voxels[:, :, int(chk_val.__str__()) - 1] = dicom_ref.pixel_array
          else: 
              print('Index: ',str(int(chk_val.__str__()) - 1), ' too large for ', i, ' skipping!')
      # Rotate and flip annotations to match volumes
      seg = scipy.ndimage.interpolation.rotate(seg, 90, reshape = False)
      for i in range(np.shape(seg)[2]):
          cur_img = np.squeeze(seg[:, :, i])
          seg[:, :, i] = np.flipud(cur_img)
      # Store volume shapes (for debug)
      if voxels.shape in shapes:
          shapes[voxels.shape] += 1
      else:
          shapes[voxels.shape] = 1
      # Saves data
      data_out.append((voxels, seg))
    return data_out

def plot_slice(slice_in, is_anns = False, num_anns = 4):
    # Plot a slice of data - can either be raw image data or corresponding annotation
    slice_in = np.squeeze(slice_in)
    plt.figure()
    plt.set_cmap(plt.bone())
    if is_anns:
        plt.pcolormesh(slice_in, vmin = 0, vmax = num_anns - 1)
    else:
        plt.pcolormesh(slice_in)
    plt.show()

##########################################################################
# Multi-slice view code extracted and adapted from: 
# https://www.datacamp.com/community/tutorials/matplotlib-3d-volumetric-data

def multi_slice_viewer(feats, anns = None, preds = None, num_classes = 4, no_axis=False):
    # Plot feats, anns, predictions in multi-slice-view
    # feats OR feats + anns OR feats + anns + preds
    if anns is None:
        fig, ax = plt.subplots()
        ax.volume = feats
        ax.index = feats.shape[-1] // 2
        ax.imshow(feats[:, :, ax.index],  cmap='bone')
        fig.canvas.mpl_connect('key_press_event', process_key)
    else:
        if preds is None:
            fig, axarr = plt.subplots(1, 2)
            plt.tight_layout()
            axarr[0].volume = feats
            axarr[0].index = 0
            axarr[0].imshow(feats[:, :, axarr[0].index],  cmap='bone')
            axarr[0].set_title('Scans')
            axarr[1].volume = anns
            axarr[1].index = 0
            axarr[1].imshow(anns[:, :, axarr[1].index],  cmap='bone', vmin = 0, vmax = num_classes)
            axarr[1].set_title('Annotations')
            fig.canvas.mpl_connect('key_press_event', process_key)
        else:
            fig, axarr = plt.subplots(1, 3)
            plt.tight_layout()
            axarr[0].volume = feats
            axarr[0].index = 0
            axarr[0].imshow(feats[:, :, axarr[0].index],  cmap='bone')
            axarr[0].set_title('Scans')
            axarr[1].volume = anns
            axarr[1].index = 0
            axarr[1].imshow(anns[:, :, axarr[1].index],  cmap='bone', vmin = 0, vmax = num_classes)
            axarr[1].set_title('Annotations')
            axarr[2].volume = preds
            axarr[2].index = 0
            axarr[2].imshow(preds[:, :, axarr[2].index],  cmap='bone', vmin = 0, vmax = num_classes)
            axarr[2].set_title('Predictions')
            fig.canvas.mpl_connect('key_press_event', process_key)
        if no_axis:
            for a in axarr:
                a.set_axis_off()
            
def process_key(event):
    # Process key_press events
    fig = event.canvas.figure
    if event.key == 'j':
        for ax in fig.axes: 
            previous_slice(ax)
    elif event.key == 'k':
        for ax in fig.axes: 
            next_slice(ax)            
    fig.canvas.draw()

def previous_slice(ax):
    # Go to the previous slice
    volume = ax.volume
    ax.index = (ax.index - 1) % volume.shape[-1]  # wrap around using %
    ax.images[0].set_array(volume[:, :, ax.index])

def next_slice(ax):
    # Go to the next slice
    volume = ax.volume
    ax.index = (ax.index + 1) % volume.shape[-1]
    ax.images[0].set_array(volume[:, :, ax.index])

# %% [markdown]
# ## 1.2. Generate dataset and export to .pkl files
#
# Generates dataset from specified folders and saves it to pickle files. <br>
# Leaderboard dataset is used as a validation set (in order to compare later design decisions and to decide when to stop training). <br>
# *Note:* This step does not need to be performed again.
#
# #### Important:
# Change the below paths to data folders, if necessary.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip '/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/train.zip'
# !unzip '/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/test.zip'
# !unzip '/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/leaderboard.zip'
# !unzip '/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/training-segm.zip'
# !unzip '/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/test-segm.zip'
# !unzip '/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/leaderboard-segm.zip'
# Out:
# Archive:  /content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/train.zip
#    creating: train/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/metadata.csv
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/LICENSE
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0001/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-79232/2.000000-t2tsetra-49698/1-15.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-17.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-18.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-19.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0002/04-14-2003-NA-MR prostaat kanker detectiemc MCAPRODET-94695/4.000000-t2tsetra320p2-76868/1-20.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-17.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-18.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-19.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-20.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-21.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-22.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-23.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0003/02-13-2003-NA-MR prostaat kanker detectiemc MCAPRODET-51154/4.000000-t2tsetra320p2-08493/1-24.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-17.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-18.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-19.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0004/04-03-2003-NA-MR prostaat kanker detectiemc MCAPRODET-78882/4.000000-t2tsetra320p2-73833/1-20.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-17.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-18.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-19.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0005/03-20-2003-NA-MR prostaat kanker detectie WDSmc MCAPRODETW-72525/4.000000-t2tsetra320p2-64593/1-20.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-17.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-18.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-19.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0006/04-28-2003-NA-MR prostaat kanker detectiemc MCAPRODET-68809/4.000000-t2tsetra320p2-09237/1-20.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-17.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-18.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-19.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0007/05-01-2003-NA-MR prostaat kanker detectiemc MCAPRODET-82639/4.000000-t2tsetra320p2-95370/1-20.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0008/05-22-2003-NA-MR prostaat kanker detectiemc MCAPRODET-35364/4.000000-t2tsetra-89294/1-15.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0009/03-15-2003-NA-MR prostaat kanker detectiemc MCAPRODET-16530/2.000000-t2tsetra-67348/1-17.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-17.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-18.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-19.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0010/02-10-2003-NA-MR prostaat kanker detectiemc MCAPRODET-32586/4.000000-t2tsetra320p2-33677/1-20.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-17.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-18.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-19.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0011/02-27-2003-NA-MR prostaat kanker detectiemc MCAPRODET-75170/4.000000-t2tsetra320p2-03399/1-20.dcm
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/
#    creating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-01.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-02.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-03.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-04.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-05.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-06.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-07.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-08.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-09.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-10.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-11.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-12.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-13.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-14.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-15.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-16.dcm
#   inflating: train/manifest-ZqaK9xEy8795217829022780222/Prostate-3T/Prostate3T-01-0012/03-06-2003-NA-MR prostaat kanker detectiemc MCAPRODET-07908/4.000000-t2tsetra320p2-04376/1-17.dcm
# ...
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-10.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-11.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-12.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-13.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-14.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-15.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-16.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-17.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-18.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-19.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-20.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-21.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-22.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-23.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-24.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-25.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-26.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-27.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-28.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-29.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-30.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-31.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-32.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-33.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0004/11-22-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-24072/701.000000-T2WTSEAX-03917/1-34.dcm
#    creating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/
#    creating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/
#    creating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-01.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-02.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-03.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-04.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-05.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-06.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-07.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-08.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-09.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-10.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-11.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-12.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-13.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-14.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-15.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-16.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-17.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-18.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-19.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-20.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-21.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-22.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-23.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-24.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-25.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-26.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-27.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-28.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-29.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-30.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-31.dcm
#   inflating: leaderboard/manifest-7v55qffK2424752658836301389/PROSTATE-DIAGNOSIS/ProstateDx-02-0005/12-13-2005-NA-MRI PROSTATE WITH AND WITHOUT CONTRAST-34346/401.000000-T2WTSEAX-85682/1-32.dcm
# Archive:  /content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/training-segm.zip
#    creating: Training/
#   inflating: Training/Prostate3T-01-0001.nrrd
#   inflating: Training/Prostate3T-01-0002.nrrd
#   inflating: Training/Prostate3T-01-0003.nrrd
#   inflating: Training/Prostate3T-01-0004.nrrd
#   inflating: Training/Prostate3T-01-0005.nrrd
#   inflating: Training/Prostate3T-01-0006.nrrd
#   inflating: Training/Prostate3T-01-0007.nrrd
#   inflating: Training/Prostate3T-01-0008.nrrd
#   inflating: Training/Prostate3T-01-0009.nrrd
#   inflating: Training/Prostate3T-01-0010.nrrd
#   inflating: Training/Prostate3T-01-0011.nrrd
#   inflating: Training/Prostate3T-01-0012.nrrd
#   inflating: Training/Prostate3T-01-0013.nrrd
#   inflating: Training/Prostate3T-01-0014.nrrd
#   inflating: Training/Prostate3T-01-0015.nrrd
#   inflating: Training/Prostate3T-01-0016.nrrd
#   inflating: Training/Prostate3T-01-0017.nrrd
#   inflating: Training/Prostate3T-01-0018.nrrd
#   inflating: Training/Prostate3T-01-0019.nrrd
#   inflating: Training/Prostate3T-01-0020.nrrd
#   inflating: Training/Prostate3T-01-0021.nrrd
#   inflating: Training/Prostate3T-01-0022.nrrd
#   inflating: Training/Prostate3T-01-0023.nrrd
#   inflating: Training/Prostate3T-01-0024.nrrd
#   inflating: Training/Prostate3T-01-0025.nrrd
#   inflating: Training/Prostate3T-01-0026.nrrd
#   inflating: Training/Prostate3T-01-0027.nrrd
#   inflating: Training/Prostate3T-01-0028.nrrd
#   inflating: Training/Prostate3T-01-0029.nrrd
#   inflating: Training/Prostate3T-01-0030.nrrd
#   inflating: Training/ProstateDx-01-0001.nrrd
#   inflating: Training/ProstateDx-01-0005.nrrd
#   inflating: Training/ProstateDx-01-0006_correctedLabels.nrrd
#   inflating: Training/ProstateDx-01-0011.nrrd
#   inflating: Training/ProstateDx-01-0013.nrrd
#   inflating: Training/ProstateDx-01-0014.nrrd
#   inflating: Training/ProstateDx-01-0019.nrrd
#   inflating: Training/ProstateDx-01-0021.nrrd
#   inflating: Training/ProstateDx-01-0023.nrrd
#   inflating: Training/ProstateDx-01-0028.nrrd
#   inflating: Training/ProstateDx-01-0035.nrrd
#   inflating: Training/ProstateDx-01-0038.nrrd
#   inflating: Training/ProstateDx-01-0042.nrrd
#   inflating: Training/ProstateDx-01-0043.nrrd
#   inflating: Training/ProstateDx-01-0044.nrrd
#   inflating: Training/ProstateDx-01-0052.nrrd
#   inflating: Training/ProstateDx-01-0054.nrrd
#   inflating: Training/ProstateDx-01-0055.nrrd
#   inflating: Training/ProstateDx-01-0056.nrrd
#   inflating: Training/ProstateDx-01-0058.nrrd
#   inflating: Training/ProstateDx-01-0059.nrrd
#   inflating: Training/ProstateDx-01-0060.nrrd
#   inflating: Training/ProstateDx-01-0063.nrrd
#   inflating: Training/ProstateDx-01-0071.nrrd
#   inflating: Training/ProstateDx-01-0073.nrrd
#   inflating: Training/ProstateDx-01-0074.nrrd
#   inflating: Training/ProstateDx-01-0075.nrrd
#   inflating: Training/ProstateDx-01-0076.nrrd
#   inflating: Training/ProstateDx-01-0080.nrrd
#   inflating: Training/ProstateDx-01-0082.nrrd
# Archive:  /content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/test-segm.zip
#    creating: Test/
#   inflating: Test/Prostate3T-03-0001_truth.nrrd
#   inflating: Test/Prostate3T-03-0002_truth.nrrd
#   inflating: Test/Prostate3T-03-0003_truth.nrrd
#   inflating: Test/Prostate3T-03-0004_truth.nrrd
#   inflating: Test/Prostate3T-03-0005_truth.nrrd
#   inflating: Test/ProstateDx-03-0001_truth.nrrd
#   inflating: Test/ProstateDx-03-0002_truth.nrrd
#   inflating: Test/ProstateDx-03-0003_truth.nrrd
#   inflating: Test/ProstateDx-03-0004_truth.nrrd
#   inflating: Test/ProstateDx-03-0005_truth.nrrd
# Archive:  /content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/leaderboard-segm.zip
#    creating: Leaderboard/
#   inflating: Leaderboard/Prostate3T-02-0001_truth.nrrd
#   inflating: Leaderboard/Prostate3T-02-0002_truth.nrrd
#   inflating: Leaderboard/Prostate3T-02-0003_truth.nrrd
#   inflating: Leaderboard/Prostate3T-02-0004_truth.nrrd
#   inflating: Leaderboard/Prostate3T-02-0005_truth.nrrd
#   inflating: Leaderboard/ProstateDx-02-0001_truth.nrrd
#   inflating: Leaderboard/ProstateDx-02-0002_truth.nrrd
#   inflating: Leaderboard/ProstateDx-02-0003_truth.nrrd
#   inflating: Leaderboard/ProstateDx-02-0004_truth.nrrd
#   inflating: Leaderboard/ProstateDx-02-0005_truth.nrrd

# %%
os.rename('/content/Leaderboard','/content/leaderboard-segm')
os.rename('/content/Test', '/content/test-segm')
os.rename('/content/Training', '/content/train-segm')

# %%
# .dcm data files
data_train_dir = '/content/train/'              
data_leader_dir = '/content/leaderboard/' 
data_test_dir = '/content/test/'

# .nrrd annotation files
anns_train_dir = '/content/train-segm/'         
anns_leader_dir = '/content/leaderboard-segm/'   
anns_test_dir = '/content/test-segm/'

# %%
train = get_dataset(data_train_dir, anns_train_dir)
# Out:
# Index:  23  too large for  ProstateDx-01-0055  skipping!
# Index:  24  too large for  ProstateDx-01-0055  skipping!
# Index:  25  too large for  ProstateDx-01-0055  skipping!
# Index:  26  too large for  ProstateDx-01-0055  skipping!
# Index:  27  too large for  ProstateDx-01-0055  skipping!
# Index:  28  too large for  ProstateDx-01-0055  skipping!
# Index:  29  too large for  ProstateDx-01-0055  skipping!
# Index:  30  too large for  ProstateDx-01-0055  skipping!
# Index:  31  too large for  ProstateDx-01-0055  skipping!
# Index:  32  too large for  ProstateDx-01-0055  skipping!
# Index:  33  too large for  ProstateDx-01-0055  skipping!

# %%
valid = get_dataset(data_leader_dir, anns_leader_dir)

# %%
test = get_dataset(data_test_dir, anns_test_dir)

# %%
if not os.path.exists('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles'):
    os.makedirs('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles')
pickle.dump(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/train.pkl', 'wb'), obj = train)
pickle.dump(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/valid.pkl', 'wb'), obj = valid)
pickle.dump(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/test.pkl', 'wb'), obj = test)

# %%
print("\nTraining scans:", len(train), "\t\t Scan slices:", np.sum([x.shape[2] for x,_ in train]), 
      "\nValidation scans:", len(valid), "\t\t Scan slices:", np.sum([x.shape[2] for x,_ in valid]), 
      "\nTesting scans: ", len(test), "\t\t Scan slices:", np.sum([x.shape[2] for x,_ in test]))
print("Sample 3D scans' shapes:", train[2][0].shape, valid[1][0].shape, test[9][0].shape) # as we can see these shapes vary
# Out:
# Training scans: 59 		 Scan slices: 1506
# Validation scans: 10 		 Scan slices: 261
# Testing scans:  10 		 Scan slices: 271
# Sample 3D scans' shapes: (320, 320, 15) (384, 384, 19) (384, 384, 19)

# %% [markdown]
# ## 1.3. Visualise scans and annotations
#
# We can verify that the loaded scans and annotations match for a sample dataset example. This indicates that the features and labels are correctly formatted.
#
# Annotation labels:
# * 0: background - black
# * 1: peripheral zone (PZ) - dark gray
# * 2: central gland (CG) - bright gray
#
# **Press 'j' or 'k' to cycle through the plots in depth (Jupyter must be run locally!).**

# %%
img_id = 12
multi_slice_viewer(train[img_id][0], train[img_id][1])
# Out:
# <div id='5c29406b-02c6-46f9-82d5-b0b487135a9a'></div>

# %% [markdown]
# ## 1.4. Class frequencies and weights
# Class weights (inversely proportional to class frequencies) will be used in the weighted cross-entropy loss function to handle class imbalance.

# %%
from collections import Counter
class_freq = {0:0, 1:0, 2:0}
for i in range(len(train)):
    for j in range(train[i][1].shape[2]):
        d = Counter(train[i][1][:,:,j].flatten())
        class_freq[0] += d[0]
        class_freq[1] += d[1]
        class_freq[2] += d[2]
print("Class frequencies in training set: ", class_freq)

inv_class_freq = 1. / np.array([class_freq[0], class_freq[1], class_freq[2]], dtype=np.float64)
class_weights = inv_class_freq / sum(inv_class_freq)
print("Class weights (inversely proportional to class frequencies): ", class_weights)
# Out:
# Class frequencies in training set:  {0: 203690867, 1: 1293924, 2: 2870825}
# Class weights (inversely proportional to class frequencies):  [0.00435971 0.68631004 0.30933025]

# %% [markdown]
# # 2. Cross-validation split [extension]
#
# Perform k-fold cross validation, as suggested in the 3D U-Net paper.
# For each fold, this needs to be run again.
#
# *Note:* **This is left as an extension and it was not performed as it would be very time-consuming. **

# %%
do_cross_val = False # Whether to do cross-validation
if do_cross_val:
    data_total = train + valid + test
    K_FOLD = 3
    VALID_FRAC = 0.25 # fraction of the training set used as validation set
    CURRENT_FOLD = 0  # need to be set to: 0, 1, ... K_FOLD-1

    val_split = len(data_total)/K_FOLD
    val_idx = CURRENT_FOLD*val_split
    train = data_total[:val_idx] + data_total[val_idx+val_split:]
    valid = train[:int(len(train)*VALID_FRAC)]
    train = train[int(len(train)*VALID_FRAC):]
    test = data_total[val_idx:val_idx+val_split]
    data_total = []

# %% [markdown]
# # 3. Data augmentation
#
# As suggested in the paper, the training dataset is **randomly** augmented with minor:
# * rotations,
# * scales and crops,
# * gray value augmentations,
# * and elastic distortions (smooth dense deformation field).
#
#
# Data augmentation is performed in the pre-processing stage (as opposed to the augmentation on-the-fly). This implies:
# * faster training
# * higher memory requirements (this is probably the reason why the paper chose the augmentation on-the-fly)

# %% [markdown]
# ## 3.1. Helper methods for data augmentation

# %%
def rotate(voxels, lbls, theta = None):
    # Rotate volume by a minor angle (+/- 10 degrees: determined by investigation of dataset variability)
    if theta is None:
        theta = random.randint(-10, 10)
    vox_new = scipy.ndimage.interpolation.rotate(voxels, theta, reshape = False)
    lbl_new = scipy.ndimage.interpolation.rotate(lbls, theta, reshape = False)
    return vox_new, lbl_new

def scale_and_crop(voxels, lbls):
    # Scale the volume by a minor size and crop around centre (can also modify for random crop)
    o_s = voxels.shape
    r_s = [0]*len(o_s)
    scale_factor = random.uniform(1, 1.2)
    vox_zoom = scipy.ndimage.interpolation.zoom(voxels, scale_factor, order=1)
    lbl_zoom = scipy.ndimage.interpolation.zoom(lbls, scale_factor, order=0)
    new_shape = vox_zoom.shape
    # Start with offset
    for i in range(len(o_s)):
        if new_shape[i] == 1: 
            r_s[i] = 0
            continue
        r_c = int(((new_shape[i] - o_s[i]) - 1)/2)
        r_s[i] = r_c
    r_e = [r_s[i] + o_s[i] for i in list(range(len(o_s)))]
    vox_zoom = vox_zoom[r_s[0]:r_e[0], r_s[1]:r_e[1], r_s[2]:r_e[2]]
    lbl_zoom = lbl_zoom[r_s[0]:r_e[0], r_s[1]:r_e[1], r_s[2]:r_e[2]]
    return vox_zoom, lbl_zoom

def grayscale_variation(voxels, lbls):
    # Introduce a random global increment in gray-level value of volume. 
    im_min = np.min(voxels)
    im_max = np.max(voxels)
    mean = np.random.normal(0, 0.1)
    smp = np.random.normal(mean, 0.01, size = np.shape(voxels))
    voxels = voxels + im_max*smp
    voxels[voxels <= im_min] = im_min # Clamp to min value
    voxels[voxels > im_max] = im_max  # Clamp to max value
    return voxels, lbls

from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter

def elastic_deformation(voxels, lbls, alpha=None, sigma=None, mode="constant", cval=0, is_random=False): 
    # Apply elastic deformation/distortion to the wolume
    # Adapted from: https://tensorlayer.readthedocs.io/en/stable/_modules/tensorlayer/prepro.html#elastic_transform
    if alpha == None:
        alpha=voxels.shape[1]*3.
    if sigma == None:
        sigma=voxels.shape[1]*0.07
    if is_random is False:
        random_state = np.random.RandomState(None)
    else:
        random_state = np.random.RandomState(int(time.time()))
        
    if len(voxels.shape) == 3:
        voxels = np.reshape(voxels, (voxels.shape[0], voxels.shape[1], voxels.shape[2], 1) )
        lbls = np.reshape(lbls, (lbls.shape[0], lbls.shape[1], lbls.shape[2], 1) )
        
    shape = (voxels.shape[0], voxels.shape[1])
    dx = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma, mode=mode, cval=cval) * alpha
    dy = gaussian_filter((random_state.rand(*shape) * 2 - 1), sigma, mode=mode, cval=cval) * alpha
    x_, y_ = np.meshgrid(np.arange(shape[0]), np.arange(shape[1]), indexing='ij')
    indices = np.reshape(x_ + dx, (-1, 1)), np.reshape(y_ + dy, (-1, 1))
    
    new_voxels = np.zeros(voxels.shape)
    new_lbls = np.zeros(lbls.shape)
    for i in range(voxels.shape[2]): # apply the same distortion to each slice within the volume
        new_voxels[:,:,i,0] = map_coordinates(voxels[:,:,i,0], indices, order=1).reshape(shape)
        new_lbls[:,:,i,0] = map_coordinates(lbls[:,:,i,0], indices, order=1).reshape(shape)
        
    return new_voxels, new_lbls

def sample_with_p(p):
    # Helper function to return boolean of a sample with given probability p
    if random.random() < p:
        return True
    else:
        return False

def get_random_perturbation(voxels, lbls):
    # Generate a random perturbation of the input feature + label
    p_rotate = 0.6
    p_scale = 0.6
    p_gray = 0.6
    p_deform = 0.6
    new_voxels, new_lbls = voxels, lbls
    if sample_with_p(p_rotate):
        new_voxels, new_lbls = rotate(new_voxels, new_lbls)
    if sample_with_p(p_scale):
        new_voxels, new_lbls = scale_and_crop(new_voxels, new_lbls)
    if sample_with_p(p_gray):
        new_voxels, new_lbls = grayscale_variation(new_voxels, new_lbls)
    if sample_with_p(p_deform):
        new_voxels, new_lbls = elastic_deformation(new_voxels, new_lbls)
    return new_voxels, new_lbls

def plot_augmentation(img_org, ann_org, img_aug, ann_aug, title_aug='Augmented', axis_off=True):
    # Plot original and augmented image along with its annotation
    # Works for different kinds of augmentations
    if len(ann_org) == 0:
        n = 1 # Annotations are not plotted
    else:
        n = 2 # Annotations are plotted
    plt.figure(figsize=(5,5))
    plt.subplot(n,2,1)
    if axis_off:
        plt.axis('off')
    plt.title("Original scan")
    plt.imshow(img_org, cmap=plt.cm.gray)
    plt.subplot(n,2,2)
    if axis_off:
        plt.axis('off')
    plt.title(title_aug)
    plt.imshow(img_aug, cmap=plt.cm.gray)
    if n > 1:
        plt.subplot(n,2,3)
        if axis_off:
            plt.axis('off')
        plt.title("Original annotation")
        plt.imshow(ann_org, cmap=plt.cm.gray)
        plt.subplot(n,2,4)
        if axis_off:
            plt.axis('off')
        plt.title(title_aug)
        plt.imshow(ann_aug, cmap=plt.cm.gray)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 3.2. Visualise data augmentations

# %%
# Load the dataset if needed
# train = pickle.load(file = open('./pickles/train.pkl', 'rb'))

img_id = 12
slice_id = 8

imgs_org = train[img_id][0]
anns_org = train[img_id][1]

img_org = train[img_id][0][:,:,slice_id]
ann_org = train[img_id][1][:,:,slice_id]

# Rotation
imgs_aug, anns_aug = rotate(imgs_org, anns_org, theta=10)
plot_augmentation(img_org, ann_org, imgs_aug[:,:,slice_id], anns_aug[:,:,slice_id], title_aug='Rotation')

# Scaling
imgs_aug, anns_aug = scale_and_crop(imgs_org, anns_org)
plot_augmentation(img_org, ann_org, imgs_aug[:,:,slice_id], anns_aug[:,:,slice_id], title_aug='Scaling')

# Gray value variation
imgs_aug, anns_aug = grayscale_variation(imgs_org, anns_org)
plot_augmentation(img_org, [], imgs_aug[:,:,slice_id], [], title_aug='Gray variation')

# Elastic deformation (smooth dense deformation field)
imgs_aug, anns_aug = elastic_deformation(imgs_org, anns_org)
plot_augmentation(img_org, ann_org, imgs_aug[:,:,slice_id,0], anns_aug[:,:,slice_id,0], title_aug='Elastic deformation')
# Out:
# <div id='57e688ab-8e3c-425f-b45e-6d29ac9c0cac'></div>
# <div id='f2977b2e-5f63-43bb-82f4-8c6e1b0ab6f1'></div>
# <div id='3e1bd2da-7558-4a3b-8959-ad21984da401'></div>
# <div id='c9153e25-f10a-4f76-a625-58a9b59e21e7'></div>

# %% [markdown]
# # 4. Data pre-processing

# %% [markdown]
# ## 4.1. Histogram equalisation
#
# Histogram equalisation (HE) is a technique used to enhance low-contrast images, by spreading out the most frequent intenshity values. The resulting equalised image has a roughly linear cumulative distribution function.
#
# HE is applied to all three paritions: train, valid and test. It further ensures that the image intensity values are within the $\left[0,1\right]$ range.

# %% [markdown]
# ### 4.1.1. Helper methods for histogram equalisation

# %%
from skimage import exposure, img_as_float

def hist_equalise(dataset):
    # Perform histogram equalisation on each scan slice 
    for i in range(len(dataset)): # Over subjects
        for j in range(dataset[i][0].shape[2]): # Over scan slices
            dataset[i][0][:,:,j] = exposure.equalize_hist(dataset[i][0][:,:,j])
            
def plot_img_and_hist(image, axes, bins=100):
    # Plot an image along with its histogram and cumulative histogram.
    # Code adapted from: http://scikit-image.org/docs/dev/auto_examples/color_exposure/plot_equalize.html
    image = img_as_float(image)
    ax_img, ax_hist = axes
    ax_cdf = ax_hist.twinx()
    
    # Display image
    ax_img.imshow(image, cmap=plt.cm.gray)
    ax_img.set_axis_off()
    
    # Display histogram
    ax_hist.hist(image.ravel(), bins=bins, histtype='step', color='black')
    ax_hist.ticklabel_format(axis='y', style='scientific', scilimits=(0, 0))
    ax_hist.set_xlabel('Pixel intensity')
    ax_hist.set_xlim(0, 1)
    ax_hist.set_yticks([])

    # Display cumulative distribution
    img_cdf, bins = exposure.cumulative_distribution(image, bins)
    ax_cdf.plot(bins, img_cdf, 'r')
    ax_cdf.set_yticks([])

    return ax_img, ax_hist, ax_cdf

def plot_histogram_equalisation(img_org, img_heq):
    # Plot original low contrast image and histogram eualised image, with their histograms and cumulative histograms.
    # Code adapted from: http://scikit-image.org/docs/dev/auto_examples/color_exposure/plot_equalize.html

    fig = plt.figure(figsize=(7, 7))
    axes = np.zeros((2, 2), dtype=np.object)
    axes[0, 0] = fig.add_subplot(2, 2, 1)
    for i in range(1, 2):
        axes[0, i] = fig.add_subplot(2, 2, 1+i, sharex=axes[0,0], sharey=axes[0,0])
    for i in range(0, 2):
        axes[1, i] = fig.add_subplot(2, 2, 3+i)

    ax_img, ax_hist, ax_cdf = plot_img_and_hist(img_org, axes[:, 0])
    ax_img.set_title('Original low contrast image')

    y_min, y_max = ax_hist.get_ylim()
    ax_hist.set_ylabel('Number of pixels')
    ax_hist.set_yticks(np.linspace(0, y_max, 5))

    ax_img, ax_hist, ax_cdf = plot_img_and_hist(img_heq, axes[:, 1])
    ax_img.set_title('Histogram equalised image')

    ax_cdf.set_ylabel('Fraction of total intensity', color='red')
    ax_cdf.set_yticks(np.linspace(0, 1, 5))

    fig.tight_layout(h_pad=-1.5)
    plt.show()

# %% [markdown]
# ### 4.1.2. Apply histogram equalisation to dataset
#
# *Note:* This step does not need to be performed again.

# %%
# Load the non-histogram equalised dataset if needed
# train = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/train.pkl', 'rb'))
# valid = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/valid.pkl', 'rb'))
# test = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/test.pkl', 'rb'))

hist_equalise(train) # in-place
hist_equalise(valid)
hist_equalise(test)

# Save histogram equalised dataset
pickle.dump(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/heq_train.pkl', 'wb'), obj = train)
pickle.dump(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/heq_valid.pkl', 'wb'), obj = valid)
pickle.dump(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/heq_test.pkl', 'wb'), obj = test)

# %% [markdown]
# ### 4.1.3 Visualise histogram equalisation

# %%
# Load the non-histogram equalised dataset as needed
# nhe_train = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/train.pkl', 'rb'))
# nhe_valid = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/valid.pkl', 'rb'))
nhe_test = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/test.pkl', 'rb'))
# Load the histogram equalised dataset as needed
# train = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/heq_train.pkl', 'rb'))
# valid = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/heq_valid.pkl', 'rb'))
test = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/heq_test.pkl', 'rb'))

# Show HE on a sample image
img_id = 9
slice_id = 10
img = nhe_test[img_id][0][:,:,slice_id]
img = img / np.max(img) # Scale to 0-1 range
img_eq = test[img_id][0][:,:,slice_id] # Already scaled to 0-1 range
plot_histogram_equalisation(img, img_eq)

# %% [markdown]
# # 4.2. Input/output scaling and IOU evaluation

# %% [markdown]
# ## 4.2.1. Helper functions for input/output scaling and IOU evaluation
# * input/output scaling: generate volume and label tensors that can be passed into the Tensorflow format and in the default `channel_last` ordering expected by Tensorflow
# * calculate Mean IOU (with respect to original unscaled labels)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
import os
import sys
import pydicom
import nrrd
import scipy.ndimage
import random
import pickle
# %matplotlib notebook

INPUT_SIZE = 120 # Input feature width/height
OUTPUT_SIZE = 120 # Output feature width/height (as defined by model)
INPUT_DEPTH = 12 # Input depth 
OFF_IMAGE_FILL = 0 # What to fill an image with if padding is required to make Tensor
OFF_LABEL_FILL = 0 # What to fill a label with if padding is required to make Tensor
OUTPUT_CLASSES = 3 # Number of output classes in dataset: the fourth class can be used for unlabelled datapoints (not needed for this dataset)

# Get 'natural' OUTPUT_DEPTH according to scipy method
io_zoom = OUTPUT_SIZE/INPUT_SIZE
zero_chk = np.zeros((INPUT_SIZE, INPUT_SIZE, INPUT_DEPTH))
OUTPUT_DEPTH = np.shape(scipy.ndimage.interpolation.zoom(zero_chk, io_zoom, order = 1))[-1]
# Alternatively, this can be forced to match expected tensorflow output (note, extra padding is applied if depth mismatch)
OUTPUT_DEPTH = 12 

def get_scaled_input(data, min_i = INPUT_SIZE, min_o = OUTPUT_SIZE, depth = INPUT_DEPTH, 
                    depth_out = OUTPUT_DEPTH, image_fill = OFF_IMAGE_FILL, 
                    label_fill = OFF_LABEL_FILL, n_classes = OUTPUT_CLASSES, norm_max = 500):
    
    # Takes raw data (x, y) and scales to match desired input and output sizes to feed into Tensorflow
    # Pads and normalises input and also moves axes around to orientation expected by tensorflow
    
    input_scale_factor = min_i/data[0].shape[0]
    output_scale_factor = min_o/data[0].shape[0]

    vox_zoom = None
    lbl_zoom = None

    if not input_scale_factor == 1:
        vox_zoom = scipy.ndimage.interpolation.zoom(data[0], input_scale_factor, order = 1) 
        # Order 1 is bilinear - fast and good enough
    else:
        vox_zoom = data[0]

    if not output_scale_factor == 1:
        lbl_zoom = scipy.ndimage.interpolation.zoom(data[1], output_scale_factor, order = 0) 
        # Order 0 is nearest neighbours: VERY IMPORTANT as it ensures labels are scaled properly (and stay discrete)
    else:
        lbl_zoom = data[1]   

    lbl_pad = label_fill*np.ones((min_o, min_o, depth_out - lbl_zoom.shape[-1]))
    lbl_zoom = np.concatenate((lbl_zoom, lbl_pad), 2)
    lbl_zoom = lbl_zoom[np.newaxis, :, :, :]
    
    vox_pad = image_fill*np.ones((min_i, min_i, depth - vox_zoom.shape[-1]))
    vox_zoom = np.concatenate((vox_zoom, vox_pad), 2)
    
    max_val = np.max(vox_zoom)
    if not np.max(vox_zoom) == 0:
        vox_zoom = vox_zoom * norm_max/np.max(vox_zoom)
        
    vox_zoom = vox_zoom[np.newaxis, :, :, :]

    vox_zoom = np.swapaxes(vox_zoom, 0, -1)
    lbl_zoom = np.swapaxes(lbl_zoom, 0, -1)
    # Swap axes
        
    return vox_zoom, lbl_zoom

def upscale_segmentation(lbl, shape_desired):
    # Returns scaled up label for a given input label and desired shape. Required for Mean IOU calculation
    
    scale_factor = shape_desired[0]/lbl.shape[0]
    lbl_upscale = scipy.ndimage.interpolation.zoom(lbl, scale_factor, order = 0)
    # Order 0 EVEN more important here
    lbl_upscale = lbl_upscale[:, :, :shape_desired[-1]]
    if lbl_upscale.shape[-1] < shape_desired[-1]:
        pad_zero = OFF_LABEL_FILL*np.zeros((shape_desired[0], shape_desired[1], shape_desired[2] - lbl_upscale.shape[-1]))
        lbl_upscale = np.concatenate((lbl_upscale, pad_zero), axis = -1)
    return lbl_upscale

def get_label_accuracy(pred, lbl_original):
    # Get pixel-wise labelling accuracy (DEMO metric)
    
    # Swap axes back
    pred = swap_axes(pred)
    pred_upscale = upscale_segmentation(pred, np.shape(lbl_original))
    return 100*np.sum(np.equal(pred_upscale, lbl_original))/np.prod(lbl_original.shape)

def get_mean_iou(pred, lbl_original, num_classes = OUTPUT_CLASSES, ret_full = False, reswap = False):
    # Get mean IOU between input predictions and target labels. Note, method implicitly resizes as needed
    # Ret_full - returns the full iou across all classes
    # Reswap - if lbl_original is in tensorflow format, swap it back into the format expected by plotting tools (+ format of raw data)
    
    # Swap axes back 
    pred = swap_axes(pred)
    if reswap:
        lbl_original = swap_axes(lbl_original)
    pred_upscale = upscale_segmentation(pred, np.shape(lbl_original))
    iou = [1]*num_classes
    for i in range(num_classes): 
        test_shape = np.zeros(np.shape(lbl_original))
        test_shape[pred_upscale == i] = 1
        test_shape[lbl_original == i] = 1
        full_sum = int(np.sum(test_shape))
        test_shape = -1*np.ones(np.shape(lbl_original))
        test_shape[lbl_original == i] = pred_upscale[lbl_original == i]
        t_p = int(np.sum(test_shape == i))
        if not full_sum == 0:
            iou[i] = t_p/full_sum
    if ret_full:
        return iou
    else: 
        return np.mean(iou)
    
def swap_axes(pred):
    # Swap those axes
    pred = np.swapaxes(pred, -1, 0)
    pred = np.squeeze(pred)
    return pred

# %% [markdown]
# ## 4.2.2. Visualise scaled scans and annotations
#
# *Note:* Run section 1.1 if it has not been executed yet.
#
# **Press 'j' or 'k' to cycle through the plots in depth (Jupyter must be run locally!).**

# %%
img_id = 15 # Image ID to view
dataset = train
x, y = get_scaled_input(dataset[img_id]) # Shows that this works - can check x,y shapes if needed
x_swap = swap_axes(x)
y_upscale = upscale_segmentation(swap_axes(y), np.shape(swap_axes(x)))
multi_slice_viewer(x_swap, y_upscale)  # View scaled images and labels together 

# Compute mean iou with itself & upsampled data
x, y = get_scaled_input(dataset[img_id])
print('Mean IOU with itself')
print(get_mean_iou(y, y, ret_full = True, reswap = True))
print('Mean IOU with original labels')
print(get_mean_iou(y, dataset[img_id][1], ret_full = True, reswap = False))
# Out:
# <div id='9bfdceeb-690f-436f-92ed-ef1f7a6b01d7'></div>
# Mean IOU with itself
# [1.0, 1.0, 1.0]
# Mean IOU with original labels
# [0.9951768924680888, 0.7293420185903535, 0.7690213222886946]

# %% [markdown]
# # 5. 3D U-Net model
#
# Set `simpleUNet` to choose if the Simplified 3D U-Net model (with one horizontal level removed) is used. This was inspired by https://github.com/mirzaevinom/prostate_segmentation.

# %%
simpleUNet = False

class UNetwork():
    
    def conv_batch_relu(self, tensor, filters, kernel = [3,3,3], stride = [1,1,1], is_training = True):
        # Produces the conv_batch_relu combination as in the paper
        padding = 'valid'
        if self.should_pad: padding = 'same'
    
        conv = tf.layers.conv3d(tensor, filters, kernel_size = kernel, strides = stride, padding = padding,
                                kernel_initializer = self.base_init, kernel_regularizer = self.reg_init)
        conv = tf.layers.batch_normalization(conv, training = is_training)
        conv = tf.nn.relu(conv) 
        return conv

    def upconvolve(self, tensor, filters, kernel = 2, stride = 2, scale = 4, activation = None):
        # Upconvolution - two different implementations: the first is as suggested in the original Unet paper and the second is a more recent version
        # Needs to be determined if these do the same thing
        padding = 'valid'
        if self.should_pad: padding = 'same'
        # upsample_routine = tf.keras.layers.UpSampling3D(size = (scale,scale,scale)) # Uses tf.resize_images
        # tensor = upsample_routine(tensor)
        # conv = tf.layers.conv3d(tensor, filters, kernel, stride, padding = 'same',
        #                                 kernel_initializer = self.base_init, kernel_regularizer = self.reg_init)
        # use_bias = False is a tensorflow bug
        conv = tf.layers.conv3d_transpose(tensor, filters, kernel_size = kernel, strides = stride, padding = padding, use_bias=False, 
                                          kernel_initializer = self.base_init,  kernel_regularizer = self.reg_init)
        return conv

    def centre_crop_and_concat(self, prev_conv, up_conv):
        # If concatenating two different sized Tensors, centre crop the first Tensor to the right size and concat
        # Needed if you don't have padding
        p_c_s = prev_conv.get_shape()
        u_c_s = up_conv.get_shape()
        offsets =  np.array([0, (p_c_s[1] - u_c_s[1]) // 2, (p_c_s[2] - u_c_s[2]) // 2, 
                             (p_c_s[3] - u_c_s[3]) // 2, 0], dtype = np.int32)
        size = np.array([-1, u_c_s[1], u_c_s[2], u_c_s[3], p_c_s[4]], np.int32)
        prev_conv_crop = tf.slice(prev_conv, offsets, size)
        up_concat = tf.concat((prev_conv_crop, up_conv), 4)
        return up_concat
        
    def __init__(self, base_filt = 8, in_depth = INPUT_DEPTH, out_depth = OUTPUT_DEPTH,
                 in_size = INPUT_SIZE, out_size = OUTPUT_SIZE, num_classes = OUTPUT_CLASSES,
                 learning_rate = 0.001, print_shapes = True, drop = 0.2, should_pad = False):
        # Initialise your model with the parameters defined above
        # Print-shape is a debug shape printer for convenience
        # Should_pad controls whether the model has padding or not
        # Base_filt controls the number of base conv filters the model has. Note deeper analysis paths have filters that are scaled by this value
        # Drop specifies the proportion of dropped activations

        # self.base_init = tf.initializers.truncated_normal (stddev=0.1) # Initialise weights
        self.base_init = tf.truncated_normal_initializer(stddev=0.1) # Initialise weights
        self.reg_init = tf.contrib.layers.l2_regularizer(scale=0.1) # Initialise regularisation (was useful)
        
        self.should_pad = should_pad # To pad or not to pad, that is the question
        self.drop = drop # Set dropout rate
        
        with tf.variable_scope('3DuNet'):
            self.training = tf.placeholder(tf.bool)
            self.do_print = print_shapes
            self.model_input = tf.placeholder(tf.float32, shape = (None, in_depth, in_size, in_size, 1))  
            # Define placeholders for feed_dict
            self.model_labels = tf.placeholder(tf.int32, shape = (None, out_depth, out_size, out_size, 1))
            labels_one_hot = tf.squeeze(tf.one_hot(self.model_labels, num_classes, axis = -1), axis = -2)
            
            if self.do_print: 
                print('Input features shape', self.model_input.get_shape())
                print('Labels shape', labels_one_hot.get_shape())
                
            # Level zero
            conv_0_1 = self.conv_batch_relu(self.model_input, base_filt, is_training = self.training)
            conv_0_2 = self.conv_batch_relu(conv_0_1, base_filt*2, is_training = self.training)
            # Level one
            max_1_1 = tf.layers.max_pooling3d(conv_0_2, [1,2,2], [1,2,2]) # Stride, Kernel previously [2,2,2]
            conv_1_1 = self.conv_batch_relu(max_1_1, base_filt*2, is_training = self.training)
            conv_1_2 = self.conv_batch_relu(conv_1_1, base_filt*4, is_training = self.training)
            conv_1_2 = tf.layers.dropout(conv_1_2, rate = self.drop, training = self.training)
            # Level two
            max_2_1 = tf.layers.max_pooling3d(conv_1_2, [1,2,2], [1,2,2]) # Stride, Kernel previously [2,2,2]
            conv_2_1 = self.conv_batch_relu(max_2_1, base_filt*4, is_training = self.training)
            conv_2_2 = self.conv_batch_relu(conv_2_1, base_filt*8, is_training = self.training)
            conv_2_2 = tf.layers.dropout(conv_2_2, rate = self.drop, training = self.training)
            
            if simpleUNet:
                # Level one
                up_conv_2_1 = self.upconvolve(conv_2_2, base_filt*8, kernel = 2, stride = [1,2,2]) # Stride previously [2,2,2]
            else:
                # Level three
                max_3_1 = tf.layers.max_pooling3d(conv_2_2, [1,2,2], [1,2,2]) # Stride, Kernel previously [2,2,2]
                conv_3_1 = self.conv_batch_relu(max_3_1, base_filt*8, is_training = self.training)
                conv_3_2 = self.conv_batch_relu(conv_3_1, base_filt*16, is_training = self.training)
                conv_3_2 = tf.layers.dropout(conv_3_2, rate = self.drop, training = self.training)
                # Level two
                up_conv_3_2 = self.upconvolve(conv_3_2, base_filt*16, kernel = 2, stride = [1,2,2]) # Stride previously [2,2,2] 
                concat_2_1 = self.centre_crop_and_concat(conv_2_2, up_conv_3_2)
                conv_2_3 = self.conv_batch_relu(concat_2_1, base_filt*8, is_training = self.training)
                conv_2_4 = self.conv_batch_relu(conv_2_3, base_filt*8, is_training = self.training)
                conv_2_4 = tf.layers.dropout(conv_2_4, rate = self.drop, training = self.training)
                # Level one
                up_conv_2_1 = self.upconvolve(conv_2_4, base_filt*8, kernel = 2, stride = [1,2,2]) # Stride previously [2,2,2]
            
            concat_1_1 = self.centre_crop_and_concat(conv_1_2, up_conv_2_1)
            conv_1_3 = self.conv_batch_relu(concat_1_1, base_filt*4, is_training = self.training)
            conv_1_4 = self.conv_batch_relu(conv_1_3, base_filt*4, is_training = self.training)
            conv_1_4 = tf.layers.dropout(conv_1_4, rate = self.drop, training = self.training)
            # Level zero
            up_conv_1_0 = self.upconvolve(conv_1_4, base_filt*4, kernel = 2, stride = [1,2,2])  # Stride previously [2,2,2]
            concat_0_1 = self.centre_crop_and_concat(conv_0_2, up_conv_1_0)
            conv_0_3 = self.conv_batch_relu(concat_0_1, base_filt*2, is_training = self.training)
            conv_0_4 = self.conv_batch_relu(conv_0_3, base_filt*2, is_training = self.training)
            conv_0_4 = tf.layers.dropout(conv_0_4, rate = self.drop, training = self.training)
            conv_out = tf.layers.conv3d(conv_0_4, OUTPUT_CLASSES, [1,1,1], [1,1,1], padding = 'same')
            self.predictions = tf.expand_dims(tf.argmax(conv_out, axis = -1), -1)
            
            # Note, this can be more easily visualised in a tool like tensorboard; Follows exact same format as in Paper.
            
            if self.do_print: 
                print('Model Convolution output shape', conv_out.get_shape())
                print('Model Argmax output shape', self.predictions.get_shape())
            
            do_weight = True
            loss_weights = [0.00439314, 0.68209101, 0.31351585] # see section 1.4 # instead of [1, 150, 100, 1.0] 
            # Weighted cross entropy: approach adapts following code: https://stackoverflow.com/questions/44560549/unbalanced-data-and-weighted-cross-entropy
            ce_loss = tf.nn.softmax_cross_entropy_with_logits_v2(logits=conv_out, labels=labels_one_hot)
            if do_weight:
                weighted_loss = tf.reshape(tf.constant(loss_weights), [1, 1, 1, 1, num_classes]) # Format to the right size
                weighted_one_hot = tf.reduce_sum(weighted_loss*labels_one_hot, axis = -1)
                ce_loss = ce_loss * weighted_one_hot
            self.loss = tf.reduce_mean(ce_loss) # Get loss
            
            self.trainer = tf.train.AdamOptimizer(learning_rate=learning_rate)
            
            self.extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS) # Ensure correct ordering for batch-norm to work
            with tf.control_dependencies(self.extra_update_ops):
                self.train_op = self.trainer.minimize(self.loss)

# %% [markdown]
# # 6. Model training

# %%
# Load the histogram equalised dataset if needed
train = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/heq_train.pkl', 'rb'))
valid = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/heq_valid.pkl', 'rb'))
test = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/heq_test.pkl', 'rb'))

# %% [markdown]
# ## 6.1. Generate pre-processed augmented dataset

# %%
# Training set: scaling & augmentation
train_run = []
augment_len = 10 # Number of perturbed data-points per raw datapoint
for i in train:
    (vox, lbl) = get_scaled_input(i)
    train_run.append((vox, lbl))
    for j in range(augment_len):
        vox_a, lbl_a = get_random_perturbation(vox, lbl)
        train_run.append((vox_a, lbl_a))
        
# Validation set: just scaling, no augmentation
valid_run = []
for i in valid:
    (vox, lbl) = get_scaled_input(i)
    valid_run.append((vox, lbl))

# %% [markdown]
# ## 6.2. Set model hyperparameters
# Set the model name `MODEL_NAME` and path `SAVE_PATH` to load a model, if any.

# %%
LEARNING_RATE = 0.001 # Model learning rate
DROPOUT = 0.1
BASE_FILT = 8    # Number of base filters
BATCH_SIZE = 10  # Batch size - VRAM limited; originally 3
PATIENCE = 5     # For early stopping: watching for validation loss increase
NUM_EPOCHS = 100 # Maximum number of training epochs
NUM_ITER = len(train_run) // BATCH_SIZE # Number of training steps per epoch
MODEL_NAME = 'FIN10a1d8f' # Model name to LOAD FROM (looks IN SAVE_PATH directory)
SAVE_PATH = "./tf/" 
LOGS_PATH = "./tf_logs/"
LOAD_MODEL = True
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)
if not os.path.exists(LOGS_PATH):
    os.makedirs(LOGS_PATH)

# %% [markdown]
# ## 6.3. Helper functions for training

# %%
def get_data_raw(data, i, batch_size):
    # Return separated x,y data from the i-th batch with the given batch size (batch_size)
    return [x[0] for x in data[i:i+batch_size]], [y[1] for y in data[i:i+batch_size]]

def get_pred_iou(predictions, lbl_original, ret_full = False, reswap = False):
    # Get mean_iou for full batch
    iou = []
    for i in range(len(lbl_original)):
        pred_cur = np.squeeze(predictions[i])
        metric = get_mean_iou(pred_cur, lbl_original[i], ret_full = ret_full, reswap = reswap)
        iou.append(metric)
    if ret_full:
        return np.mean(iou, axis = 0)
    else:
        return np.mean(iou)

# %% [markdown]
# ## 6.4. Train model
#
# Train for `NUM_EPOCHS` epochs with early stopping on validation loss increase, with the patience `PATIENCE` epochs. Checkpoint the model periodically.

# %%
print(NUM_ITER, " iterations per epoch")
tf.compat.v1.reset_default_graph()
unet = UNetwork(drop = DROPOUT, base_filt = BASE_FILT, should_pad = True, learning_rate = LEARNING_RATE) # MODEL DEFINITION
init = tf.global_variables_initializer()
saver = tf.train.Saver(tf.global_variables(), max_to_keep=4*PATIENCE)
config = tf.ConfigProto()

with tf.Session(config=config) as sess:
    writer = tf.summary.FileWriter(LOGS_PATH, graph=tf.get_default_graph())
    if LOAD_MODEL:
        print('Trying to load saved model...')
        try:
            print('Loading from: ', SAVE_PATH + MODEL_NAME+ '.meta')
            restorer = tf.train.import_meta_graph(SAVE_PATH + MODEL_NAME+ '.meta')
            restorer.restore(sess, tf.train.latest_checkpoint(SAVE_PATH))
            print("Model sucessfully restored")
        except IOError:
            sess.run(init)
            print("No previous model found, running default init") 
    
    train_losses = []
    val_losses = []
    val_IOUs = []
    patience_cnt = 0
    train_times = []
    
    for e in range(NUM_EPOCHS):
        
        start_time = time.time()
        
        # Shuffle the training data
        random.shuffle(train_run)
        
        curr_train_loss = []
        for i in range(NUM_ITER): # Iterate over batches within the epoch
            print('Current epoch: ',e,', iteration: ',i,'/',NUM_ITER, end='\r')
            x, y = get_data_raw(train_run, i, BATCH_SIZE)
            train_dict = {
                unet.training: True,
                unet.model_input: x,
                unet.model_labels: y
            }
            _,loss = sess.run([unet.train_op, unet.loss], feed_dict = train_dict) # Train on batch and get train loss
            curr_train_loss.append(loss)
            
        # Evaluate train and valid loss
        train_loss = np.mean(curr_train_loss)
        x, y = get_data_raw(valid_run, 0, len(valid_run)) # scaled
        _, orig_y = get_data_raw(valid, 0, len(valid))    # non-scaled (for IOU evaluation)
        valid_dict = {
            unet.training: False,
            unet.model_input: x,
            unet.model_labels: y
        }
        val_loss = sess.run(unet.loss, feed_dict = valid_dict) # Get valid loss
    
        # Predict on validation set and calculate IOU
        val_preds = np.squeeze(sess.run([unet.predictions], feed_dict = valid_dict))
        iou = get_pred_iou(val_preds, orig_y, ret_full = True)
        val_IOUs.append(iou)
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        print("Epoch ",e, "\t train_loss = ", train_loss, "\t val_loss = ", val_loss, "\t val_IOU = ", np.mean(iou))
        
        if e > 0:
            start_time = train_times[-1]
            if e % 5 == 0:
                print('Saving model at epoch: ', e) # Save periodically
                saver.save(sess, SAVE_PATH + MODEL_NAME, global_step = e)

            if val_losses[-1] > val_losses[-2]:
                patience_cnt += 1
            else:
                patience_cnt = 0
                
        train_times.append( time.time() - start_time )
        
        if patience_cnt >= PATIENCE:
            print("Early stopping ...")
            saver.save(sess, SAVE_PATH + MODEL_NAME + '-final', global_step = e)
            break
            
# The trace below is just an example
# Out:
# 64  iterations per epoch
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Input features shape (?, 12, 120, 120, 1)
# Labels shape (?, 12, 120, 120, 3)
# WARNING:tensorflow:From <ipython-input-39-0cce34ba83c1>:11: conv3d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv3D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:632: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-39-0cce34ba83c1>:12: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From <ipython-input-39-0cce34ba83c1>:74: max_pooling3d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling3D instead.
# WARNING:tensorflow:From <ipython-input-39-0cce34ba83c1>:77: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From <ipython-input-39-0cce34ba83c1>:27: conv3d_transpose (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv3DTranspose` instead.
# Model Convolution output shape (?, 12, 120, 120, 3)
# Model Argmax output shape (?, 12, 120, 120, 1)
# Trying to load saved model...
# Loading from:  ./tf/FIN10a1d8f.meta
# No previous model found, running default init
# Epoch  0 	 train_loss =  0.008373155 	 val_loss =  0.20067638 	 val_IOU =  0.1304722446925995
# Epoch  1 	 train_loss =  0.005789806 	 val_loss =  0.009965977 	 val_IOU =  0.23505483275501893
# Epoch  2 	 train_loss =  0.005024401 	 val_loss =  0.008326943 	 val_IOU =  0.23051257848876525
# Epoch  3 	 train_loss =  0.004540979 	 val_loss =  0.010973592 	 val_IOU =  0.3436065962886042
# Epoch  4 	 train_loss =  0.005023193 	 val_loss =  0.00419069 	 val_IOU =  0.336761679086887
# Epoch  5 	 train_loss =  0.0038060953 	 val_loss =  0.006155421 	 val_IOU =  0.3235400061190575
# Saving model at epoch:  5
# Epoch  6 	 train_loss =  0.004206949 	 val_loss =  0.009346625 	 val_IOU =  0.3349760753257362
# Epoch  7 	 train_loss =  0.0043828445 	 val_loss =  0.006262892 	 val_IOU =  0.3255852850493411
# Epoch  8 	 train_loss =  0.00444375 	 val_loss =  0.003294153 	 val_IOU =  0.3569742252120723
# Epoch  9 	 train_loss =  0.004003455 	 val_loss =  0.0049928334 	 val_IOU =  0.3374956250591518
# Epoch  10 	 train_loss =  0.004622914 	 val_loss =  0.007443314 	 val_IOU =  0.3336282713795287
# Saving model at epoch:  10
# Epoch  11 	 train_loss =  0.0042213215 	 val_loss =  0.0048847566 	 val_IOU =  0.37451984638306407
# Epoch  12 	 train_loss =  0.0039673187 	 val_loss =  0.01443646 	 val_IOU =  0.34450272959368705
# Epoch  13 	 train_loss =  0.0040863436 	 val_loss =  0.0043328605 	 val_IOU =  0.3785382341663755
# Epoch  14 	 train_loss =  0.0042472454 	 val_loss =  0.0045710984 	 val_IOU =  0.35487627356064383
# Epoch  15 	 train_loss =  0.003595293 	 val_loss =  0.007050049 	 val_IOU =  0.37088726670858047
# Saving model at epoch:  15
# Epoch  16 	 train_loss =  0.0033570528 	 val_loss =  0.005921709 	 val_IOU =  0.3526507768815213
# Epoch  17 	 train_loss =  0.0033199394 	 val_loss =  0.0062306174 	 val_IOU =  0.3304784413857684
# Epoch  18 	 train_loss =  0.0033257501 	 val_loss =  0.004092349 	 val_IOU =  0.3669096551768108
# Epoch  19 	 train_loss =  0.0035900103 	 val_loss =  0.008126513 	 val_IOU =  0.38208865181347784
# Epoch  20 	 train_loss =  0.0038728039 	 val_loss =  0.0057285144 	 val_IOU =  0.34755673270983606
# Saving model at epoch:  20
# Epoch  21 	 train_loss =  0.0033629593 	 val_loss =  0.0033413013 	 val_IOU =  0.3862118107669646
# Epoch  22 	 train_loss =  0.0032131155 	 val_loss =  0.004374403 	 val_IOU =  0.34680343514252243
# Epoch  23 	 train_loss =  0.003206355 	 val_loss =  0.005491591 	 val_IOU =  0.36421889801340873
# Epoch  24 	 train_loss =  0.0031287735 	 val_loss =  0.0036280572 	 val_IOU =  0.3999990243506233
# Epoch  25 	 train_loss =  0.003781108 	 val_loss =  0.00733801 	 val_IOU =  0.3450302732131605
# Saving model at epoch:  25
# Epoch  26 	 train_loss =  0.0035775644 	 val_loss =  0.004174526 	 val_IOU =  0.3736376946312669
# Epoch  27 	 train_loss =  0.0038881074 	 val_loss =  0.005193521 	 val_IOU =  0.37635889153740876
# Epoch  28 	 train_loss =  0.003522994 	 val_loss =  0.005117427 	 val_IOU =  0.3455916074082129
# Epoch  29 	 train_loss =  0.0038303398 	 val_loss =  0.0043722265 	 val_IOU =  0.30695369858545646
# Epoch  30 	 train_loss =  0.0036822902 	 val_loss =  0.005818451 	 val_IOU =  0.33752544547449564
# Saving model at epoch:  30
# Epoch  31 	 train_loss =  0.0036446275 	 val_loss =  0.0043829936 	 val_IOU =  0.35652031742780393
# Epoch  32 	 train_loss =  0.003272257 	 val_loss =  0.005532573 	 val_IOU =  0.3651421041103123
# Epoch  33 	 train_loss =  0.003196569 	 val_loss =  0.0073312614 	 val_IOU =  0.38021281045358585
# Epoch  34 	 train_loss =  0.0032300823 	 val_loss =  0.008202381 	 val_IOU =  0.3698656924049128
# Epoch  35 	 train_loss =  0.003453678 	 val_loss =  0.0035799246 	 val_IOU =  0.36297299928338433
# Saving model at epoch:  35
# Epoch  36 	 train_loss =  0.003069805 	 val_loss =  0.006962968 	 val_IOU =  0.36888975485159636
# Epoch  37 	 train_loss =  0.0030026198 	 val_loss =  0.0052854777 	 val_IOU =  0.38322663017390246
# Epoch  38 	 train_loss =  0.003164229 	 val_loss =  0.0048429584 	 val_IOU =  0.3912404611978601
# Epoch  39 	 train_loss =  0.0035911503 	 val_loss =  0.0043576052 	 val_IOU =  0.33180083049633846
# Epoch  40 	 train_loss =  0.0036392137 	 val_loss =  0.0042866385 	 val_IOU =  0.3743953410523299
# Saving model at epoch:  40
# Epoch  41 	 train_loss =  0.0037971488 	 val_loss =  0.0076309345 	 val_IOU =  0.3772408785886751
# Epoch  42 	 train_loss =  0.0034217895 	 val_loss =  0.0041535962 	 val_IOU =  0.353625572737229
# Epoch  43 	 train_loss =  0.0031198976 	 val_loss =  0.0054115625 	 val_IOU =  0.3880005962370991
# Epoch  44 	 train_loss =  0.0031273062 	 val_loss =  0.0042121094 	 val_IOU =  0.3978218669780616
# Epoch  45 	 train_loss =  0.0031003924 	 val_loss =  0.006391902 	 val_IOU =  0.3887480530715555
# Saving model at epoch:  45
# Epoch  46 	 train_loss =  0.0032137197 	 val_loss =  0.0052432558 	 val_IOU =  0.413270996004365
# Epoch  47 	 train_loss =  0.0028043506 	 val_loss =  0.00816915 	 val_IOU =  0.3608660078030397
# Epoch  48 	 train_loss =  0.003009229 	 val_loss =  0.005535193 	 val_IOU =  0.37506277469207916
# Epoch  49 	 train_loss =  0.0030642813 	 val_loss =  0.00522832 	 val_IOU =  0.3729336226499446
# Epoch  50 	 train_loss =  0.0036106808 	 val_loss =  0.0031882697 	 val_IOU =  0.34845629346499063
# Saving model at epoch:  50
# Epoch  51 	 train_loss =  0.003195212 	 val_loss =  0.0033404897 	 val_IOU =  0.3811283338583044
# Epoch  52 	 train_loss =  0.0031904806 	 val_loss =  0.003853048 	 val_IOU =  0.38414793876913667
# Epoch  53 	 train_loss =  0.003325746 	 val_loss =  0.008661651 	 val_IOU =  0.3840748875219406
# Epoch  54 	 train_loss =  0.0029438958 	 val_loss =  0.005807764 	 val_IOU =  0.4049435893890954
# Epoch  55 	 train_loss =  0.0029471985 	 val_loss =  0.0041340184 	 val_IOU =  0.3923880298260982
# Saving model at epoch:  55
# Epoch  56 	 train_loss =  0.0025890158 	 val_loss =  0.00437692 	 val_IOU =  0.3904412135467506
# Epoch  57 	 train_loss =  0.0032212087 	 val_loss =  0.003498292 	 val_IOU =  0.3762852210874002
# Epoch  58 	 train_loss =  0.0027249553 	 val_loss =  0.0037862833 	 val_IOU =  0.39817519032376275
# Epoch  59 	 train_loss =  0.0029892595 	 val_loss =  0.0034064723 	 val_IOU =  0.39438697791835575
# Epoch  60 	 train_loss =  0.003034159 	 val_loss =  0.0028450238 	 val_IOU =  0.3574429891308187
# Saving model at epoch:  60
# Epoch  61 	 train_loss =  0.00327593 	 val_loss =  0.005123871 	 val_IOU =  0.40223935993326565
# Epoch  62 	 train_loss =  0.0033632126 	 val_loss =  0.008004006 	 val_IOU =  0.35979585075254833
# Epoch  63 	 train_loss =  0.0025259187 	 val_loss =  0.008100003 	 val_IOU =  0.37120319927482875
# Epoch  64 	 train_loss =  0.0033842912 	 val_loss =  0.005862483 	 val_IOU =  0.3631343319271478
# Epoch  65 	 train_loss =  0.0029778087 	 val_loss =  0.0072384817 	 val_IOU =  0.37172145548271734
# Saving model at epoch:  65
# Epoch  66 	 train_loss =  0.0022939807 	 val_loss =  0.005813446 	 val_IOU =  0.3930311190893782
# Epoch  67 	 train_loss =  0.0031165527 	 val_loss =  0.009855204 	 val_IOU =  0.39019699896839266
# Epoch  68 	 train_loss =  0.002184623 	 val_loss =  0.008975627 	 val_IOU =  0.3884042282405107
# Epoch  69 	 train_loss =  0.0029461668 	 val_loss =  0.008232949 	 val_IOU =  0.3799504429157335
# Epoch  70 	 train_loss =  0.0029536283 	 val_loss =  0.009258183 	 val_IOU =  0.3911217076874682
# Saving model at epoch:  70
# Epoch  71 	 train_loss =  0.0033754734 	 val_loss =  0.008737943 	 val_IOU =  0.3841914258738603
# Epoch  72 	 train_loss =  0.0028066055 	 val_loss =  0.004313635 	 val_IOU =  0.3796876775378073
# Epoch  73 	 train_loss =  0.0022811282 	 val_loss =  0.004253112 	 val_IOU =  0.4071264825977381
# Epoch  74 	 train_loss =  0.0027565523 	 val_loss =  0.0055771465 	 val_IOU =  0.41162881878918284
# Epoch  75 	 train_loss =  0.0025971641 	 val_loss =  0.0039270762 	 val_IOU =  0.37348232742525034
# Saving model at epoch:  75
# Epoch  76 	 train_loss =  0.003179212 	 val_loss =  0.0077093947 	 val_IOU =  0.4070118789549982
# Epoch  77 	 train_loss =  0.0030441044 	 val_loss =  0.0039425464 	 val_IOU =  0.4008621500143981
# Epoch  78 	 train_loss =  0.0023763021 	 val_loss =  0.005618192 	 val_IOU =  0.4185981639566752
# Epoch  79 	 train_loss =  0.0028483195 	 val_loss =  0.014061091 	 val_IOU =  0.37219908147074854
# Epoch  80 	 train_loss =  0.0029110136 	 val_loss =  0.0089986455 	 val_IOU =  0.4030939659004213
# Saving model at epoch:  80
# Epoch  81 	 train_loss =  0.0024635284 	 val_loss =  0.005701509 	 val_IOU =  0.3902623971528612
# Epoch  82 	 train_loss =  0.0028696144 	 val_loss =  0.006009312 	 val_IOU =  0.36848685634607237
# Epoch  83 	 train_loss =  0.0027251802 	 val_loss =  0.007983062 	 val_IOU =  0.38217837041893077
# Epoch  84 	 train_loss =  0.0026548542 	 val_loss =  0.017021002 	 val_IOU =  0.36163688092570306
# Epoch  85 	 train_loss =  0.002819682 	 val_loss =  0.006697555 	 val_IOU =  0.36411769232001107
# Saving model at epoch:  85
# Epoch  86 	 train_loss =  0.0022963365 	 val_loss =  0.0044266726 	 val_IOU =  0.37409045476554365
# Epoch  87 	 train_loss =  0.002204741 	 val_loss =  0.006406493 	 val_IOU =  0.41049535440100215
# Epoch  88 	 train_loss =  0.0025934856 	 val_loss =  0.015334943 	 val_IOU =  0.36229866444088493
# Epoch  89 	 train_loss =  0.0024001852 	 val_loss =  0.012754436 	 val_IOU =  0.3705343438589411
# Epoch  90 	 train_loss =  0.0021634889 	 val_loss =  0.009123749 	 val_IOU =  0.38567337277805797
# Saving model at epoch:  90
# Epoch  91 	 train_loss =  0.002418036 	 val_loss =  0.008277857 	 val_IOU =  0.39845112063668003
# Epoch  92 	 train_loss =  0.0027529055 	 val_loss =  0.004915695 	 val_IOU =  0.39377538177654287
# Epoch  93 	 train_loss =  0.0027516317 	 val_loss =  0.0042637507 	 val_IOU =  0.4154495740144997
# Epoch  94 	 train_loss =  0.0021583405 	 val_loss =  0.004929872 	 val_IOU =  0.37429218490743615
# Epoch  95 	 train_loss =  0.002677444 	 val_loss =  0.007601171 	 val_IOU =  0.374482206944211
# Saving model at epoch:  95
# Epoch  96 	 train_loss =  0.002648254 	 val_loss =  0.0065896814 	 val_IOU =  0.3929135477415091
# Epoch  97 	 train_loss =  0.002370648 	 val_loss =  0.004165941 	 val_IOU =  0.4000310848112589
# Epoch  98 	 train_loss =  0.0025314465 	 val_loss =  0.0048218467 	 val_IOU =  0.3919492791244407
# Epoch  99 	 train_loss =  0.0023487976 	 val_loss =  0.006718174 	 val_IOU =  0.3924078739562474

# %%
# Save training history
np.savez('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/' + MODEL_NAME + '.npz', train_losses=train_losses, val_losses=val_losses, val_IOUs=val_IOUs, 
         train_times=train_times)

# %%
# Load training history
#MODEL_NAME = 'm10a1d'
hist = np.load('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/' + MODEL_NAME + '.npz')
train_losses = hist['train_losses']
val_losses = hist['val_losses']
val_IOUs = hist['val_IOUs']
train_times = hist['train_times']

# %%
# Show training history
mean_val_IOUs = [np.mean(iou) for iou in val_IOUs]
print("Minimum validation loss: ", np.min(val_losses), " at epoch ", np.argmin(val_losses))
print("Maximum validation IOU: ", np.max(mean_val_IOUs), " at epoch ", np.argmax(mean_val_IOUs))
print("Last validation loss: ", val_losses[-1])
print("Last validation IOU: ", mean_val_IOUs[-1])

# Loss Curves
plt.figure()
x = np.arange(len(train_losses))
plt.plot(x, train_losses,'r-')
plt.plot(x, val_losses,'b-')
plt.legend(['Training loss', 'Validation loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0, 0.1)
plt.show()

# Validation IOU
plt.figure()
plt.plot(x, mean_val_IOUs,'b-')
plt.xlabel('Epoch')
plt.ylabel('Validatio IOU')
plt.show()
# Out:
# Minimum validation loss:  0.0028450238  at epoch  60
# Maximum validation IOU:  0.4185981639566752  at epoch  78
# Last validation loss:  0.006718174
# Last validation IOU:  0.3924078739562474
# <div id='9dd8405d-1758-4e85-8f17-143246ee9dc1'></div>
# <div id='2828aef8-d352-4bec-8446-6aabb2579cb0'></div>

# %% [markdown]
# # 7. Model inference
#
# Predict with the trained model on the test set and calculate IOUs.
#
# #### Important:
# If sections 4.1 and 5 have not been executed, execute them before proceeding. <br>
# Iff section 6.4 has not been executed, run the following cell.

# %%
unet = UNetwork(drop = DROPOUT, base_filt = BASE_FILT, should_pad = True)

# %%
TEST_MODEL_NAME = MODEL_NAME
SAVE_PATH = "./tf/" 
BATCH_SIZE = 10 # was 3 originally

# Load the test set
#test = pickle.load(file = open('./pickles/heq_test.pkl', 'rb'))

config = tf.ConfigProto()
test_predictions = []
with tf.Session(config=config) as sess:
    print('Loading saved model ...')
    restorer = tf.train.import_meta_graph(SAVE_PATH + TEST_MODEL_NAME + '-95.meta')
    restorer.restore(sess, SAVE_PATH + TEST_MODEL_NAME + '-95')
    print("Model sucessfully restored")
    pred_out = [] # Predictions for each test scan
    x_orig = []   # list of non-scaled scans
    y_orig = []   # list of non-scaled annotations
    x_in = []
    y_in = []
    i = 0
    iou_out = []  # IOUs for each test scan

    while i < len(test): # Iterate over batches
        x_batch = []
        y_batch = []
        for j in range(i, min(len(test), i + BATCH_SIZE)): # Iterate over samples within the batch
            x_orig.append(np.copy(test[j][0]))
            y_orig.append(np.copy(test[j][1]))
            x_cur, y_cur = get_scaled_input(test[j])
            x_batch.append(x_cur)
            y_batch.append(y_cur)
        if len(x_batch) == 0: break
        print('Processing ', i)
        x_in = x_in + x_batch
        y_in = y_in + y_batch
        test_dict = {
            unet.training: False, # Whether to perform batch-norm at inference (Paper says this would be useful)
            unet.model_input: x_batch,
            unet.model_labels: y_batch
        }
        test_predictions = np.squeeze(sess.run([unet.predictions], feed_dict = test_dict))
        if len(x_batch) == 1:
            pred_out.append(test_predictions)
        else:
            pred_out.extend([np.squeeze(test_predictions[z, :, :, :]) for z in list(range(len(x_batch)))])
        i += BATCH_SIZE

    for i in range(len(y_orig)):
        iou = get_mean_iou(pred_out[i], y_orig[i], ret_full = True)
        print('Test scan', i,': IOUs: ', iou, 'Mean: ', np.mean(iou))
        iou_out.append(np.mean(iou))
    print('Mean test IOU', np.mean(iou_out), 'Std IOU', np.std(iou_out)) # mean over all test scans
    
# Save test predictions
pickle.dump(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/pred_' + TEST_MODEL_NAME + '.pkl', 'wb'), obj = pred_out)
# Out:
# Loading saved model ...
# INFO:tensorflow:Restoring parameters from ./tf/FIN10a1d8f-95
# Model sucessfully restored
# Processing  0
# Test scan 0 : IOUs:  [0.9626091912904706, 0.0733490893924649, 0.0709971783634508] Mean:  0.36898515301546214
# Test scan 1 : IOUs:  [0.9727974632926005, 0.08670603126305484, 0.0075788432445013385] Mean:  0.3556941126000523
# Test scan 2 : IOUs:  [0.9851910560525851, 0.1254898545676217, 0.1050648807032231] Mean:  0.4052485971078099
# Test scan 3 : IOUs:  [0.9719985087227881, 0.021257166049414033, 0.08916415935812902] Mean:  0.3608066113767771
# Test scan 4 : IOUs:  [0.9539655017580702, 0.05269594521143602, 0.16050384777365137] Mean:  0.38905509824771917
# Test scan 5 : IOUs:  [0.9565986269228968, 0.020731451443696636, 0.08576037542161608] Mean:  0.35436348459606987
# Test scan 6 : IOUs:  [0.9615710181695236, 0.10124962479660027, 0.3492442673301115] Mean:  0.4706883034320784
# Test scan 7 : IOUs:  [0.977925614812603, 0.10365586253637922, 0.25199150773920775] Mean:  0.44452432836273
# Test scan 8 : IOUs:  [0.9719541129828568, 0.03698312058614757, 0.1537253716066901] Mean:  0.38755420172523153
# Test scan 9 : IOUs:  [0.9720960270398866, 0.04389114070642733, 0.15635259864956946] Mean:  0.39077992213196117
# Mean test IOU 0.3927699812595892 Std IOU 0.03658894965245964

# %%
# (Optional) If loading previously saved predictions

TEST_MODEL_NAME = MODEL_NAME
pred_out = pickle.load(file = open('/content/gdrive/MyDrive/NCI-ISBI 2013 Prostate MRI/pickles/pred_' + TEST_MODEL_NAME + '.pkl', 'rb'))

x_orig = []   # list of non-scaled scans
y_orig = []
for i in range(len(test)):
    x_orig.append(np.copy(test[i][0]))
    y_orig.append(np.copy(test[i][1]))
    
iou_out = []  # IOUs for each test scan
for i in range(len(y_orig)):
    iou = get_mean_iou(pred_out[i], y_orig[i], ret_full = True)
    print('Test scan', i,': IOUs: ', iou, 'Mean: ', np.mean(iou))
    iou_out.append(np.mean(iou))
print('\nMean test IOU', np.mean(iou_out), 'Std IOU', np.std(iou_out)) # mean over all test scans
print("Best prediction on the test scan: ", np.argmax(iou_out))
print("Worst prediction on the test scan: ", np.argmin(iou_out))
# Out:
# Test scan 0 : IOUs:  [0.9626091912904706, 0.0733490893924649, 0.0709971783634508] Mean:  0.36898515301546214
# Test scan 1 : IOUs:  [0.9727974632926005, 0.08670603126305484, 0.0075788432445013385] Mean:  0.3556941126000523
# Test scan 2 : IOUs:  [0.9851910560525851, 0.1254898545676217, 0.1050648807032231] Mean:  0.4052485971078099
# Test scan 3 : IOUs:  [0.9719985087227881, 0.021257166049414033, 0.08916415935812902] Mean:  0.3608066113767771
# Test scan 4 : IOUs:  [0.9539655017580702, 0.05269594521143602, 0.16050384777365137] Mean:  0.38905509824771917
# Test scan 5 : IOUs:  [0.9565986269228968, 0.020731451443696636, 0.08576037542161608] Mean:  0.35436348459606987
# Test scan 6 : IOUs:  [0.9615710181695236, 0.10124962479660027, 0.3492442673301115] Mean:  0.4706883034320784
# Test scan 7 : IOUs:  [0.977925614812603, 0.10365586253637922, 0.25199150773920775] Mean:  0.44452432836273
# Test scan 8 : IOUs:  [0.9719541129828568, 0.03698312058614757, 0.1537253716066901] Mean:  0.38755420172523153
# Test scan 9 : IOUs:  [0.9720960270398866, 0.04389114070642733, 0.15635259864956946] Mean:  0.39077992213196117
#
# Mean test IOU 0.3927699812595892 Std IOU 0.03658894965245964
# Best prediction on the test scan:  6
# Worst prediction on the test scan:  5

# %% [markdown]
# ## 7.1. Visualise predictions
#
# To choose which test scan to show predictions on, pick `img_id` $\in \{0, 1, ... 9\}$.
# The IOUs calculated in the above cell indicate which test scans obtained the best predictions and are therefore the best ones to visualise.
#
# *Note:* Run section 1.1 if it has not been executed yet.

# %% [markdown]
# ### 7.1.1 Example: 'best' prediction
#
# We can see that even though the predictions for CG appear earlier and predictions for PZ disappear slightly later than they should, the predictions in the middle match the annotations very well. In general, the sample predictions indicate that the model rather overestimates the size of the prostate.

# %%
img_id = 6
x_cur = x_orig[img_id]
y_cur = y_orig[img_id]
y_upscale = upscale_segmentation(swap_axes(pred_out[img_id][:, :, :, np.newaxis]), np.shape(x_cur))
multi_slice_viewer(x_cur, y_cur, y_upscale) # View  images, labels and predictions together
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 7.1.2. Example: 'worst' prediction
#
# We can see that there are almost no CG region predictions and the PZ is predicted at wrong positions. This may be caused by insufficient variability of the training data.

# %%
img_id = 5
x_cur = x_orig[img_id]
y_cur = y_orig[img_id]
y_upscale = upscale_segmentation(swap_axes(pred_out[img_id][:, :, :, np.newaxis]), np.shape(x_cur))
multi_slice_viewer(x_cur, y_cur, y_upscale) # View  images, labels and predictions together
# Out:
# <img src="data:image/png;base64,..." width="640">
